# %%
from tensorflow.keras.models import load_model
from nltk.stem import WordNetLemmatizer
import numpy as np
import random
import pickle
import json
import nltk

# %%
lemmatizer = WordNetLemmatizer()

conversations = json.loads(open('dataset.json', encoding='utf-8').read())

conversations
# Out:
# {'chatbot': [{'tag': 'greetings',
#    'intent': ['Hey', 'Hi', 'Hello, i need to know', 'How is it going'],
#    'response': ['Good day',
#     "Hope you're doing okay ?",
#     'i am fine .',
#     'fine',
#     'what would you like to know .']},
#   {'tag': 'complaint',
#    'intent': ['i dont understand .'],
#    'response': ['from where ?', 'where should i start from', 'which part?']},
#   {'tag': 'please what form is this',
#    'intent': ['please what form is this', 'what is this form about'],
#    'response': ['Is a form that helps you get around your registration issues']},
#   {'tag': "i don't know my color",
#    'intent': ["i don't know my color",
#     'what is my color',
#     'how can i know my color',
#     'how do i know the color that i belong to',
#     'Which colour indicate your academic standing .'],
#    'response': ['you can either be green, yellow, orange or red',
#     'i am green']},
#   {'tag': 'what is the registration student academic service .',
#    'intent': ['what is the registration student academic service',
#     'registration student academic service is what'],
#    'response': []},
#   {'tag': 'can you get exempted form the UFS module?',
#    'intent': ['can you get exempted form the UFS module?',
#     'is it possible to get exempted module form',
#     'how possible or easier is it to get exempted ufs module form'],
#    'response': ["no you can't be exempted from the UFS module, it is compulsory"]},
#   {'tag': "I'm academically excluded, does that mean I cannot continue with the next semester's modules ?",
#    'intent': ["I'm academically excluded, does that mean I cannot continue with the next semester's modules"],
#    'response': ['yes contact the deans office']},
#   {'tag': 'how do i access blackboard',
#    'intent': ['how do i access blackboard',
#     'how can someone access black board'],
#    'response': ['go to UFS website to access blackboard']},
#   {'tag': 'how do i sign in on blackboard app',
#    'intent': ['how do i sign in on blackboard app',
#     'how can someone signin to blackboard app',
#     'how can i login to my blackboard portal'],
#    'response': ['use your username and password to sign in on the blackboard app']},
#   {'tag': 'i am in need of funding what do i do ',
#    'intent': ['i am in need of funding what do i do',
#     'i need funding what can i do',
#     'how can i access funding',
#     'how do i get funding',
#     'can you fund me'],
#    'response': ['Contact financial aids if you need funding']},
#   {'tag': "I'm struggling to register online",
#    'intent': ['how do i register online ',
#     "why can't i register online ?",
#     "i'm finding it difficult to register online, why ?"],
#    'response': ['maybe you have financial hold .',
#     'maybe you have academic advisement hold .',
#     'maybe you have international hold .',
#     'is your color red ?',
#     'your color is red .']},
#   {'tag': 'If my academic standing is green, what do I need to do ?',
#    'intent': ['If my academic standing is green, what do I need to do ?',
#     'my academic standing is green .',
#     'what if i am green ?'],
#    'response': ['You are excellent ',
#     'You passed 100% of your modules .',
#     'You have never changed your programme plan .',
#     'No action required .',
#     'You are on track ',
#     'You may proceed to register online ',
#     'Should you have additional queries, however, you are welcome to contact your advisor ',
#     'No hold or block on your record .']},
#   {'tag': 'If my academic standing is yellow, what do I need to do ?',
#    'intent': ["what if i'm a yellow one ?",
#     'If my academic standing is yellow, what do I need to do ?',
#     'my academic standing is yellow .',
#     'what if i am yellow ?'],
#    'response': ["You haven't made any programme plan changes ",
#     'Proceed to register online, but first register the modules you failed .']},
#   {'tag': 'If my academic standing is yellow one, what do I need to do ?',
#    'intent': ['If my academic standing is yellow one, what do I need to do ?'],
#    'response': ['You did not pass all your modules, but you are still  on track .']},
#   {'tag': 'If my academic standing is yellow two or yellow three, what do I need to do ?',
#    'intent': ['If my academic standing is yellow two, what do I need to do ?',
#     'If my academic standing is yellow three, what do I need to do ?'],
#    'response': ['You have failed modules in the past and changed your academic plan or programme .',
#     'You have never failed credits or modules, but changed your academic programme or plan']},
#   {'tag': 'does red indicate a good academic standing ?',
#    'intent': ['does red indicate a good academic standing ?',
#     'my color is red, what does it mean ?'],
#    'response': ['You are high piority']},
#   {'tag': 'what kind of form required to change an incomplete qualification ?',
#    'intent': ['what kind of form required to change an incomplete qualification ?',
#     'how can i change an incomplete qualification ?'],
#    'response': ["you're to fill a DV2 form", 'it is DV2 form']},
#   {'tag': 'is UFS 101 a compulsory module?',
#    'intent': ['is UFS 101 a compulsory module ?'],
#    'response': ['it is a compulsory module']},
#   {'tag': 'what is an elective module ?',
#    'intent': ['what is an elective module ?', 'elective module is what ?'],
#    'response': ['Elective module is chosen by the student from the list given by the institute in a given semester .']},
#   {'tag': 'I have clicked on the enroll link but I am still not enrolled for the selected modules .',
#    'intent': ['I have clicked on the enroll link but I am still not enrolled for the selected modules .',
#     'how do i enroll for a module ?'],
#    'response': ['Make sure you selected the checkboxes for the modules you need to register for .']},
#   {'tag': 'how do i register online ?',
#    'intent': ['how do i register online ?', 'can i register online ?'],
#    'response': ['Log into Student Self-Service, and select programme enrollment to register online .']},
#   {'tag': 'what are the requirements to register ?',
#    'intent': ['what are the requirements to register ?',
#     'what do i need to register ?',
#     'i want to register .'],
#    'response': ["if you're a new student pay registration fees of 7500 or contact student finance .",
#     'you will pay registration fees of 7500 or contact student finance if you are a new student .']},
#   {'tag': 'i am having problem to do my education plan .',
#    'intent': ['i am having problem to do my education plan .',
#     "i can't get my education plan done "],
#    'response': ['Go to UFS website and check the learning programme information in the departmental year book .',
#     'head to the UFS website and check the learning program information in the department year book .']},
#   {'tag': 'when do registration start and end ?',
#    'intent': ['when do registration start and end ?',
#     'when will registration end ?',
#     'when will registartion start ?'],
#    'response': ['you will find it on the university website under student self service .',
#     'under student self service in the university website .']},
#   {'tag': 'how can i add or drop a module ?',
#    'intent': ['how can i add or drop a module ?',
#     'i want to drop a module .',
#     'i want to add a module .',
#     'how can i add a module?',
#     'how can i drop a module ?'],
#    'response': ['You can do it online on student self-service or contact your programme director .',
#     'contact your programme director .',
#     'you can do it online in the university website .']},
#   {'tag': "i'm unable to select my modules",
#    'intent': ["i can't select my module", 'i am unable to select my modules'],
#    'response': ['Contact student academic services 0514019111 .',
#     'you can call student service at 0514019111 .',
#     'contact academic services at 0514019111 .']},
#   {'tag': "I'm a NSFAS student and I have outstanding fees. Will I be allowed to register?",
#    'intent': ["I'm a NSFAS student and I have outstanding fees. Will I be allowed to register?",
#     'i havce outstanding fees will i be allowed to register ?'],
#    'response': ['Contact student finance 0514019111 .']},
#   {'tag': 'how much is my registration fees ?',
#    'intent': ['how much is my registration fees ?',
#     'my registration fees cost how much ?',
#     'how much will i pay for registration ?'],
#    'response': ['go to ufs website and check student self service option .']},
#   {'tag': 'Where can I find out more information about academic support?',
#    'intent': ['Where can I find out more information about academic support ?',
#     'i need more information about academic support',
#     'what is academic support ?',
#     'where can i find academic support ?'],
#    'response': ['Contact student academic service or call 0514019666']},
#   {'tag': 'I have forgotten my password, how do I regain access to register',
#    'intent': ['I have forgotten my password, how do I regain access to register',
#     'i forgot my password',
#     'i cant remeber my password .',
#     'how can i regain access to register ?'],
#    'response': ['Go to UFS website, check student self-service for student password management']},
#   {'tag': 'what should i do after registration ?',
#    'intent': ['what should i do after registration ?'],
#    'response': ['Print your proof of registration from student self-service on UFS website']},
#   {'tag': 'Do I have to pay for registration if my NSFAS funds were approved?',
#    'intent': ['Do I have to pay for registration if my NSFAS funds were approved ?',
#     'if my NSFAS funds were approved do i need to pay?'],
#    'response': ['Contact student finance office or call 0514019111']},
#   {'tag': 'would failing a module cost me and extra year ?',
#    'intent': ['would failing a module cost me and extra year ?',
#     'if i fail a module will i have an extra year ?'],
#    'response': ['contact your programme director .']},
#   {'tag': 'i have registered my modules under the wrong code .',
#    'intent': ['i registerd my modules under the wrong code .',
#     'i have registered my modules under the wrong code .',
#     'what should i do if i register wrong code ?',
#     'what should i do if i register wrong modules ?'],
#    'response': ['contact your programme director .']},
#   {'tag': 'what happens if i fail a module ?',
#    'intent': ['what happens if i fail a module ?',
#     'i failed a module what should i do ?',
#     'failed module what next ?'],
#    'response': ['You re-registered the module. Also contact your programme director',
#     'register for the module again .',
#     'contact your programme director .']},
#   {'tag': 'What do I need to do if I did not study for a year and willing to return to finish ?',
#    'intent': ['What do I need to do if I did not study for a year and willing to return to finish ?',
#     'i want to defere',
#     'i would like to return and finish .'],
#    'response': ['you apply for degree again ?', 'apply for degree .']},
#   {'tag': 'I failed my modules and I was told that I did not meet the requirements to continue is there something I can do?',
#    'intent': ['I failed my modules and I was told that I did not meet the requirements to continue is there something I can do ?',
#     'i do not meet requirements ',
#     'i do not meet requirements to continue .'],
#    'response': ['contact the deans office for appeals']},
#   {'tag': 'how much are tuition fees ?',
#    'intent': ['how much are tuition fees ?',
#     'what is the cost for tuition fees ?',
#     'tuiton fees cost ?',
#     'tuition fees'],
#    'response': ['Go to UFS website and check student self-service option for fees year book or you can generate the quotation online']},
#   {'tag': "I'm academically excluded, does that mean I cannot continue with the next semester's modules",
#    'intent': ["I'm academically excluded, does that mean I cannot continue with the next semester's modules .",
#     'academically excluded .'],
#    'response': ['yes contact the deans office .']},
#   {'tag': 'I registered for an incorrect module, how can I enroll for the correct one?',
#    'intent': ['I registered for an incorrect module, how can I enroll for the correct one ?',
#     'how can i enroll for correct module .',
#     'what do i do if i register incorrect module?'],
#    'response': ['contact your programme director is the quickest way .',
#     'Log into Student Self-Service, drop the incorrect module and add the correct module .',
#     'drop the course and register the right module .']},
#   {'tag': 'how much is my registration of the course i choose to study ?',
#    'intent': ['how much is my registration of the course i choose to study ?'],
#    'response': ['Go to UFS website, check student self-service for fees year book .']},
#   {'tag': 'I paid my own registration fees and received NSFAS thereafter, can I get a refund',
#    'intent': ['I paid my own registration fees and received NSFAS thereafter, can I get a refund',
#     'can i get refund ?',
#     'i paid my own registration fees .'],
#    'response': ['Contact student finance 0514019111 .']},
#   {'tag': "Where do I get assistance if I don't understand my module content ?",
#    'intent': ["Where do I get assistance if I don't understand my module content?",
#     'where can i geyt assistance ?',
#     'i dont understand my module content.'],
#    'response': ['contact your module presenter or your lecture',
#     'contact your lecturer']},
#   {'tag': 'would NAFAS fund me if i fail any modules ?',
#    'intent': ['would NAFAS still fund me if i fail any modules ?',
#     'will i still get funds from NAFAS if i fail a module ?'],
#    'response': ['contact NAFAS for appeal']},
#   {'tag': 'what are the university banking details ?',
#    'intent': ['what are the university banking details ?',
#     'how can i find the university banking details ?',
#     'does the university have a banking details ?',
#     'can i pay online ?',
#     'university banking details'],
#    'response': ['You can find it on the university website and check student finance']},
#   {'tag': 'What do I do if my modules do not appear on Blackboard?',
#    'intent': ['What do I do if my modules do not appear on Blackboard ?',
#     'my modules do not appear on the blackboard ',
#     'i cant find my modules on the blackboard app'],
#    'response': ['Call help desk for blackboard enquiries or call 0514012000 .']},
#   {'tag': 'How long does it take for modules to appear or disappear on Blackboard?',
#    'intent': ['How long does it take for modules to appear or disappear on Blackboard?'],
#    'response': ['Call help desk for blackboard enquiries or call 0514012000 .']},
#   {'tag': 'how much does it cost to add a module not funded',
#    'intent': ['how much does it cost to add a module not funded'],
#    'response': ['Contact student finance or go to UFS website and check student finance to generate quotation .']},
#   {'tag': 'can i choose courses accross departments ?',
#    'intent': ['can i choose courses accross departments ?',
#     'can i choose modules across departments ?'],
#    'response': ['you can but contact your programme director .']},
#   {'tag': 'How can I contact the international office staff during registration ?',
#    'intent': ['How can I contact the international office staff during registration ?',
#     'contact during registration'],
#    'response': ['Via email or call 0514013219']},
#   {'tag': 'how much do i pay ?',
#    'intent': ['how much do i pay ?', 'what does it cost ?'],
#    'response': ['Contact student finance office or call 0514019111']},
#   {'tag': 'can i register with my study visa reciept ?',
#    'intent': ['can i register with my study visa reciept ?',
#     'can i submit my study visa reciept ?'],
#    'response': ['yes but call international office on 0514013219 .']},
#   {'tag': 'i am in need of funding what should i do ?',
#    'intent': ['i am in need of funding what do i do',
#     'if i need funds what can i do ?',
#     'i need supposrt what should i do ?',
#     'do they offer funds? ',
#     'do they offer support? '],
#    'response': ['Contact financial aids if you need funding ,',
#     'Contact financial aids']},
#   {'tag': 'I have accepted the offer, what is my next step?',
#    'intent': ['I have accepted the offer, what is my next step ?',
#     'i accept the offer'],
#    'response': ['go and register .', 'register on the university website .']},
#   {'tag': 'What are the other funding options besides NSFAS?',
#    'intent': ['What are the other funding options besides NSFAS?'],
#    'response': ['check online bursaries awarded by the university .']},
#   {'tag': 'What documents do I need to submit for registration at the international office ?',
#    'intent': ['What documents do I need to submit for registration at the international office ?',
#     'what documents are needed for registration at the international office ?',
#     'international office documents'],
#    'response': ['Contact international office for list of document to submit on 0514013219']},
#   {'tag': 'can i use my medical aid to register ?',
#    'intent': ['can i register with my medical aid ?',
#     'can i use my mediacal aid to register ?'],
#    'response': ['Yes, but contact student finance because there is a process to follow']},
#   {'tag': 'can you get exempted form the UFS module?',
#    'intent': ['can you get exempted form the UFS module?'],
#    'response': ['no you cant']},
#   {'tag': 'If my academic standing is orange, what do I need to do ?',
#    'intent': ['If my academic standing is yellow one, what do I need to do ?',
#     "what if i'm a yellow one ?",
#     'If my academic standing is yellow, what do I need to do ?',
#     'my academic standing is yellow .',
#     'what if i am yellow ?'],
#    'response': ['all students with no color allocated yet',
#     'if you still need help after this conversation please contact your faculty academic supervisor']},
#   {'tag': 'If my academic standing is orange one, what do I need to do ?',
#    'intent': ['If my academic standing is orange one, what do I need to do ?',
#     "what if i'm a orange one ?",
#     'If my academic standing is orange, what do I need to do ?',
#     'my academic standing is orange .',
#     'what if i am orange ?'],
#    'response': ['you have failed module more than twice',
#     'you are a piority student .',
#     'you cannot continue with online registration without having a conversation with your faculty academic advisor .']},
#   {'tag': 'If my academic standing is orange three, what do I need to do ?',
#    'intent': ['If my academic standing is orange three, what do I need to do ?',
#     "what if i'm a orange one ?",
#     'If my academic standing is orange, what do I need to do ?',
#     'my academic standing is orange three.',
#     'what if i am orange three ?'],
#    'response': ['you have failed an elective module more than twice',
#     'contact your faculty academic advisor']},
#   {'tag': 'what is a core module ?',
#    'intent': ['what is a core module ? ', 'what is a compulsory module ?'],
#    'response': ['core module is a compulsory module']},
#   {'tag': 'which module is compulsory ?',
#    'intent': ['what are compulsory module?'],
#    'response': ['AGAN 1508 is a compulsory module titled language literacy English .',
#     'EALN 1508 is a compulsory module titled language literacy Afrikaan',
#     'UFS 101 is a compulsory module titled ethics, values and life skills',
#     'BCIS 1513 is a compulsory module titled introduction to information systems']},
#   {'tag': 'which module is elective ?',
#    'intent': ['what are elective module ?', 'which is elective module ?'],
#    'response': ['CHEM 1514 is an elective module and the content is inorganic and analytical chemistry.',
#     'CHEM 1624 is an elective module content includes organic and physical chemistry .',
#     'MATM 1534 is an elective module content is calculus .',
#     'MATM 1544 is an elective module content is calculus and linear algebra ']},
#   {'tag': 'name .',
#    'intent': ['what is your name and color ?'],
#    'response': ['i am Ednah Aliyu i am orange two']}]}

# %%
words = pickle.load(open('chat_words.pkl', 'rb'))
classes = pickle.load(open('chat_classes.pkl', 'rb'))
model = load_model('text_chatbot_model.h5,chatbot')

classes
# Out:
# ['Do I have to pay for registration if my NSFAS funds were approved?',
#  'How can I contact the international office staff during registration ?',
#  'How long does it take for modules to appear or disappear on Blackboard?',
#  'I failed my modules and I was told that I did not meet the requirements to continue is there something I can do?',
#  'I have accepted the offer, what is my next step?',
#  'I have clicked on the enroll link but I am still not enrolled for the selected modules .',
#  'I have forgotten my password, how do I regain access to register',
#  'I paid my own registration fees and received NSFAS thereafter, can I get a refund',
#  'I registered for an incorrect module, how can I enroll for the correct one?',
#  "I'm a NSFAS student and I have outstanding fees. Will I be allowed to register?",
#  "I'm academically excluded, does that mean I cannot continue with the next semester's modules",
#  "I'm academically excluded, does that mean I cannot continue with the next semester's modules ?",
#  "I'm struggling to register online",
#  'If my academic standing is green, what do I need to do ?',
#  'If my academic standing is orange one, what do I need to do ?',
#  'If my academic standing is orange three, what do I need to do ?',
#  'If my academic standing is orange, what do I need to do ?',
#  'If my academic standing is yellow one, what do I need to do ?',
#  'If my academic standing is yellow two or yellow three, what do I need to do ?',
#  'If my academic standing is yellow, what do I need to do ?',
#  'What are the other funding options besides NSFAS?',
#  'What do I do if my modules do not appear on Blackboard?',
#  'What do I need to do if I did not study for a year and willing to return to finish ?',
#  'What documents do I need to submit for registration at the international office ?',
#  'Where can I find out more information about academic support?',
#  "Where do I get assistance if I don't understand my module content ?",
#  'can i choose courses accross departments ?',
#  'can i register with my study visa reciept ?',
#  'can i use my medical aid to register ?',
#  'can you get exempted form the UFS module?',
#  'complaint',
#  'does red indicate a good academic standing ?',
#  'greetings',
#  'how can i add or drop a module ?',
#  'how do i access blackboard',
#  'how do i register online ?',
#  'how do i sign in on blackboard app',
#  'how much are tuition fees ?',
#  'how much do i pay ?',
#  'how much does it cost to add a module not funded',
#  'how much is my registration fees ?',
#  'how much is my registration of the course i choose to study ?',
#  'i am having problem to do my education plan .',
#  'i am in need of funding what do i do ',
#  'i am in need of funding what should i do ?',
#  "i don't know my color",
#  'i have registered my modules under the wrong code .',
#  "i'm unable to select my modules",
#  'is UFS 101 a compulsory module?',
#  'name .',
#  'please what form is this',
#  'what are the requirements to register ?',
#  'what are the university banking details ?',
#  'what happens if i fail a module ?',
#  'what is a core module ?',
#  'what is an elective module ?',
#  'what is the registration student academic service .',
#  'what kind of form required to change an incomplete qualification ?',
#  'what should i do after registration ?',
#  'when do registration start and end ?',
#  'which module is compulsory ?',
#  'which module is elective ?',
#  'would NAFAS fund me if i fail any modules ?',
#  'would failing a module cost me and extra year ?']

# %%
def clean_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    return sentence_words

# %%
def bag_of_words(sentence):
    sentence_words = clean_sentence(sentence)
    bag = [0] * len(words)
    
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

# %%
def predict_class(sentence):
    bow = bag_of_words(sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    for i in res:
        results = [[i, r] for i, r in enumerate(res)if r > ERROR_THRESHOLD]
        results.sort(key=lambda x : x[1], reverse=True)
        if results == [[i, r] for i, r in enumerate(res)if r < ERROR_THRESHOLD]:
            return 'get'
        
        
        
    return_list = []
    for r in results:
        return_list.append({'chatbot': classes[r[0]], 'probablity': str(r[1])})
    return return_list

# %%
def get_response(conversations_list, conversation_json):
    
    tag = conversations_list[0]["chatbot"]  
    list_of_conversations = conversation_json['chatbot']
    for i in list_of_conversations:
        if i['tag'] == tag:
            result = random.choice(i['response'])
            break
    return result
# print('Go! Bot is running..........')
    
# while True:
#     message = input("")
#     ints = predict_class(message)
#     res = get_response(ints, conversations)
#     print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 19>()
#      10     return result
#      11 # print('Go! Bot is running..........')
#      12
#      13 # while True:
#    (...)
#      16 #     res = get_response(ints, conversations)
#      17 #     print(res)
# ---> 19 print(conversations_list[0]["chatbot"])
#
# NameError: name 'conversations_list' is not defined
